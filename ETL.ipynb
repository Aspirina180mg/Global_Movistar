# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
# Lee el archivo Excel
df = pd.read_excel('Datasets\Solicitudes_17_08.xlsx')

# Muestra las primeras filas del DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     663 non-null    int64
#  1   Rut_Cliente            663 non-null    object
#  2   Razon Social           663 non-null    object
#  3   Rut Madre              663 non-null    object
#  4   Razon Social Madre     120 non-null    object
#  5   Segmento               663 non-null    object
#  6   Sub_segmento           663 non-null    object
#  7   rut_asesor             663 non-null    object
#  8   ase_negocio            663 non-null    object
#  9   Jefatura               663 non-null    object
#  10  sub_gerente_ventas     663 non-null    object
#  11  Venta Movil            663 non-null    int64
#  12  Venta fijo             663 non-null    int64
#  13  M2M                    663 non-null    int64
# ...

# %%
df = df.drop(columns=['Rut Madre'])
df = df.drop(columns=['Razon Social Madre'])
#df = df.drop(columns=['Rut Madre'])
#df = df.drop(columns=['Rut Madre'])
#df = df.drop(columns=['Rut Madre'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663 entries, 0 to 662
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     663 non-null    int64
#  1   Rut_Cliente            663 non-null    object
#  2   Razon Social           663 non-null    object
#  3   Segmento               663 non-null    object
#  4   Sub_segmento           663 non-null    object
#  5   rut_asesor             663 non-null    object
#  6   ase_negocio            663 non-null    object
#  7   Jefatura               663 non-null    object
#  8   sub_gerente_ventas     663 non-null    object
#  9   Venta Movil            663 non-null    int64
#  10  Venta fijo             663 non-null    int64
#  11  M2M                    663 non-null    int64
#  12  SSPP                   663 non-null    int64
#  13  Cluster                351 non-null    object
# ...

# %%
df.describe()
# Out:
#                  Id   Venta Movil  Venta fijo    M2M   SSPP  Movil rep legal  \
# count    663.000000  6.630000e+02       663.0  663.0  663.0     6.630000e+02
# mean   46729.859729  1.838786e+04         0.0    0.0    0.0     1.864687e+09
# std      216.139075  1.140164e+05         0.0    0.0    0.0     7.158194e+09
# min    46355.000000 -8.640230e+05         0.0    0.0    0.0     6.142873e+07
# 25%    46543.500000  0.000000e+00         0.0    0.0    0.0     9.550505e+08
# 50%    46729.000000  0.000000e+00         0.0    0.0    0.0     9.799745e+08
# 75%    46924.000000  0.000000e+00         0.0    0.0    0.0     9.921094e+08
# max    47100.000000  1.549862e+06         0.0    0.0    0.0     5.699918e+10
#
#        Fijo rep legal  Fecha ingreso
# count    6.630000e+02   6.630000e+02
# mean     6.988880e+08   2.021081e+07
# std      3.154290e+09   4.957783e+00
# min      0.000000e+00   2.021080e+07
# 25%      2.200000e+08   2.021080e+07
# 50%      2.200000e+08   2.021081e+07
# ...
